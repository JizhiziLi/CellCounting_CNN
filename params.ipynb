# %%
import pickle
def load_params(params_file):
    f=open(params_file,'rb')
    layer0_params=pickle.load(f)
    layer1_params=pickle.load(f)
    layer2_params=pickle.load(f)
    layer3_params=pickle.load(f)
    f.close()
    return layer0_params,layer1_params,layer2_params,layer3_params

# layer0_params,layer1_params,layer2_params,layer3_params=load_params('./params/linear_count_params.pkl')
layer0_params,layer1_params,layer2_params,layer3_params=load_params('./params/logistic_zeroOne_params.pkl')
print('finish')

# print(layer0_params[0].__class__.__name__)
# print(layer0_params[0].shape )
# print(layer0_params[0])

# print(layer0_params[0].eval())
print(layer0_params[0].eval().shape)
print(layer1_params[0].eval().shape)
print(layer2_params[0].eval().shape)
print(layer3_params[0].eval().shape)
# print(layer2_params[0].eval()[1])
# print(layer2_params[0].eval()[1])
# print(layer3_params[0].eval())
print(layer3_params[0].eval())
# Out:
# finish
# (5, 1, 5, 5)
# (10, 5, 5, 5)
# (810, 100)
# (100, 2)
# [[-0.08138592  0.08138592]
#  [-0.08866752  0.08866752]
#  [ 0.02313424 -0.02313424]
#  [-0.00086597  0.00086597]
#  [-0.12028521  0.12028521]
#  [-0.05825691  0.05825691]
#  [-0.03461628  0.03461628]
#  [-0.07219113  0.07219113]
#  [ 0.11060205 -0.11060205]
#  [-0.01060375  0.01060375]
#  [-0.07527699  0.07527699]
#  [-0.04771981  0.04771981]
#  [ 0.05908322 -0.05908322]
#  [-0.05188048  0.05188048]
#  [-0.0077379   0.0077379 ]
#  [ 0.02145799 -0.02145799]
#  [-0.01290482  0.01290482]
#  [ 0.08968038 -0.08968038]
#  [ 0.03282792 -0.03282792]
#  [ 0.04564782 -0.04564782]
#  [-0.16838155  0.16838155]
#  [-0.02399636  0.02399636]
#  [-0.076096    0.076096  ]
#  [-0.07178435  0.07178435]
#  [-0.01658451  0.01658451]
#  [-0.0196915   0.0196915 ]
#  [-0.03916878  0.03916878]
#  [-0.07866307  0.07866307]
#  [ 0.03001875 -0.03001875]
#  [ 0.09011593 -0.09011593]
#  [ 0.04743968 -0.04743968]
#  [ 0.11069546 -0.11069546]
# ...

# %%
import pickle
def load_params(params_file):
    f=open(params_file,'rb')
    layer0_params=pickle.load(f)
    layer1_params=pickle.load(f)
    layer2_params=pickle.load(f)
    layer3_params=pickle.load(f)
    f.close()
    return layer0_params,layer1_params,layer2_params,layer3_params

layer0_params,layer1_params,layer2_params,layer3_params=load_params('./hehe.pkl')
print('finish')

print(layer0_params[0].__class__.__name__)
print(layer0_params[0].shape )
print(layer0_params[0])

# print(layer0_params[0].eval())
print(layer0_params[0].eval())
print(layer0_params[0].eval().shape)
print(layer1_params[0].eval().shape)
print(layer2_params[0].eval().shape)
print(layer3_params[0].eval().shape)
# print(layer2_params[0].eval()[1])
# print(layer2_params[0].eval()[1])
# print(layer3_params[0].eval())
# Out:
# finish
# TensorVariable
# Shape.0
# Subtensor{int64}.0
# ---------------------------------------------------------------------------
# MissingInputError                         Traceback (most recent call last)
# <ipython-input-7-935468d966f5> in <module>()
#      17
#      18 # print(layer0_params[0].eval())
# ---> 19 print(layer0_params[0].eval())
#      20 print(layer0_params[0].eval().shape)
#      21 print(layer1_params[0].eval().shape)
#
# /Users/jizhizili/anaconda/lib/python3.5/site-packages/theano/gof/graph.py in eval(self, inputs_to_values)
#     518         inputs = tuple(sorted(inputs_to_values.keys(), key=id))
#     519         if inputs not in self._fn_cache:
# --> 520             self._fn_cache[inputs] = theano.function(inputs, self)
#     521         args = [inputs_to_values[param] for param in inputs]
#     522
#
# ...

# %%
import pickle
def load_params(params_file):
    f=open(params_file,'rb')
    layer0_params=pickle.load(f)
    layer1_params=pickle.load(f)
    layer2_params=pickle.load(f)
    layer3_params=pickle.load(f)
    f.close()
    return layer0_params,layer1_params,layer2_params,layer3_params

layer0_params,layer1_params,layer2_params,layer3_params=load_params('./logistic_zeroOne_params.pkl')
print('finish')

print(layer0_params[0].__class__.__name__)
print(layer0_params[0].shape )
print(layer0_params[0])

# print(layer0_params[0].eval())
print(layer0_params[0].eval().shape)
print(layer1_params[0].eval().shape)
print(layer2_params[0].eval().shape)
print(layer3_params[0].eval().shape)
print(layer3_params[0].eval()[1])
# Out:
# finish
# TensorSharedVariable
# Shape.0
# <TensorType(float64, 4D)>
# (6, 1, 5, 5)
# (18, 6, 5, 5)
# (1458, 100)
# (100, 2)
# [ 0.00169891 -0.00169891]

# %%
import pickle
def load_params(params_file):
    f=open(params_file,'rb')
    layer0_params=pickle.load(f)
    layer1_params=pickle.load(f)
    layer2_params=pickle.load(f)
    layer3_params=pickle.load(f)
    f.close()
    return layer0_params,layer1_params,layer2_params,layer3_params

layer0_params,layer1_params,layer2_params,layer3_params=load_params('./logistic_count_params.pkl')
print('finish')

print(layer0_params[0].__class__.__name__)
print(layer0_params[0].shape )
print(layer0_params[0])

# print(layer0_params[0].eval())
print(layer0_params[0].eval().shape)
print(layer1_params[0].eval().shape)
print(layer2_params[0].eval().shape)
print(layer3_params[0].eval().shape)
print(layer3_params[0].eval()[1])
# Out:
# finish
# TensorSharedVariable
# Shape.0
# <TensorType(float64, 4D)>
# (5, 1, 5, 5)
# (10, 5, 5, 5)
# (810, 100)
# (100, 17)
# [-0.13853986 -0.41533242  0.07429115  0.2124578   0.24448654  0.08786211
#  -0.00592958 -0.00592958 -0.00592958 -0.00592958 -0.00592958 -0.00592958
#  -0.00592958 -0.00592958 -0.00592958 -0.00592958 -0.00592958]
